# %% [markdown]
# # Goal

# %% [markdown]
# You need to estimate the total flow of oil, gas, and water through a choke valve. The total flow rate is labeled `QTOT`. You should use all measurements that may explain the total flow. Awesome Corp has already prepared these for you in a dataset (no further preprocessing is required). The measurements (features) are labeled as follows:
# - `CHK`: choke opening - a number in [0, 1], 1 meaning fully open and 0 meaning closed
# - `PWH`: pressure upstream the choke (scaled)
# - `PDC`: pressure downstream the choke (scaled)
# - `TWH`: temperature upstream the choke (scaled)
# - `FGAS`: fraction of gas to total flow - a number in [0,1]
# - `FOIL`: fraction of water to total flow - a number in [0,1]
#
# The location of the sensors are shown in the figure below.
#
# <img src="well_sensors.png">
#
# ### Wait! There is one issue. The customer does not have a model for the total flow rate...
#
# A simple choke model for water flow is:
# $$QTOT = C_v(CHK) \sqrt{\frac{2(PWH - PDC)}{\rho}}$$
# where $C_v(CHK)$ gives the cross-sectional area as a function of choke opening `CHK`.
#
# Unfortunately, there are complications that prevent us from using this model:
#
# 1. We do not know what the correct equations are for multi-phase flow. For example, we expect gas expansions to be a factor. This factor is likely dependent on the temperature `TWH` and the amount of gas `FGAS`. Viscosity is probably a factor too, and that would depend on `FOIL`.
# 2. We do not know the form of the choke $C_v$-curve.
#
# [Head scratch] Perhaps we can use a deep learning algorithm to learn a good representation of the data? Let us try to use all the available measurements to model `QTOT` using a neural network:
# $$QTOT = f_{\theta}(CHK, PWH, PDC, TWH, FGAS, FOIL)$$
#
# Let's get to work!

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dense
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# # Dataset

# %%
df = pd.read_csv('well_data.csv', index_col=0)
df
# Out:
#         CHK       PWH       PDC       TWH      FGAS      FOIL       QTOT
# 0     0.540  0.542755  0.211586  0.594760  0.138882  0.861118  32.358228
# 1     0.540  0.542755  0.211586  0.594760  0.142222  0.857774  32.940225
# 2     0.894  0.458000  0.222654  0.616555  0.144697  0.855303  48.633042
# 3     0.894  0.452311  0.222556  0.609029  0.144938  0.855056  48.065657
# 4     0.894  0.443485  0.221839  0.602488  0.144187  0.855807  47.096656
# ...     ...       ...       ...       ...       ...       ...        ...
# 3094  0.534  0.462606  0.215561  0.592627  0.128039  0.826061  28.108285
# 3095  0.534  0.462854  0.216331  0.589506  0.127935  0.825378  28.119254
# 3096  0.534  0.463855  0.239411  0.594895  0.127857  0.824711  27.875849
# 3097  0.415  0.498174  0.234317  0.581882  0.129256  0.833875  18.412828
# 3098  0.541  0.463279  0.216901  0.592885  0.127476  0.822423  28.678289
#
# [3099 rows x 7 columns]

# %%
fig, ax = plt.subplots(2, 2, figsize=(16, 9))

# Choke valve opening
ax[0, 0].plot(df['CHK'], label='CHK', color="blue")
ax[0, 0].legend()

# Total floqw through choke valve
ax[0, 1].plot(df['TWH'], label='TWH', color='orange')
ax[0, 1].legend()

# Diff pressure over choke valve
ax[1, 0].plot(df['PWH'] - df['PDC'], label='PWH - PDC', color='green')
ax[1, 0].legend()

# Fractions
ax[1, 1].plot(df['FOIL'], label='FOIL')
ax[1, 1].plot(df['FGAS'], '--r', label='FGAS')
ax[1, 1].legend()

# %%
df.corr()
# Out:
#            CHK       PWH       PDC       TWH      FGAS      FOIL      QTOT
# CHK   1.000000 -0.963694  0.706279  0.285622  0.091705 -0.087384  0.935945
# PWH  -0.963694  1.000000 -0.690669 -0.262040 -0.053365  0.097010 -0.889464
# PDC   0.706279 -0.690669  1.000000  0.086445 -0.071751 -0.103538  0.647044
# TWH   0.285622 -0.262040  0.086445  1.000000  0.070121 -0.096992  0.372099
# FGAS  0.091705 -0.053365 -0.071751  0.070121  1.000000 -0.375864  0.189640
# FOIL -0.087384  0.097010 -0.103538 -0.096992 -0.375864  1.000000 -0.096468
# QTOT  0.935945 -0.889464  0.647044  0.372099  0.189640 -0.096468  1.000000

# %%
def show_heatmap(data):
    plt.matshow(data.corr())
    plt.xticks(range(data.shape[1]), data.columns, fontsize=14, rotation=90)
    plt.gca().xaxis.tick_bottom()
    plt.yticks(range(data.shape[1]), data.columns, fontsize=14)

    cb = plt.colorbar()
    cb.ax.tick_params(labelsize=14)
    plt.title("Feature Correlation Heatmap", fontsize=14)
    plt.show()


show_heatmap(df)

# %% [markdown]
# ## Split into training, validation and test data.

# %% [markdown]
# ### Test data

# %%
test_set = df[2000:2500]

x_test = test_set.drop(columns='QTOT')
y_test = test_set[['QTOT']]

# %% [markdown]
# ### Validation data

# %%
#train_val_set = df.copy().drop(test_set.index) 
train_val_set = df.iloc[0:500]

val_set = train_val_set.sample(frac=0.1, replace=False)

x_val = val_set.drop(columns='QTOT')
y_val = val_set[['QTOT']]

# %% [markdown]
# ### Training data

# %%
train_set = train_val_set.copy().drop(val_set.index)

x_train = train_set.drop(columns='QTOT')
y_train = train_set[['QTOT']]

# %%
plt.figure(figsize=(16,9))
plt.scatter(y_train.index, y_train.values, color='black', label='Train')
plt.scatter(val_set.index, val_set['QTOT'], color='green', label='Val')
plt.scatter(y_test.index, y_test.values, color='red', label='test')
plt.legend()

# %% [markdown]
# # Simple model

# %%
from keras import regularizers

input_layer_size = x_train.columns.size

model = keras.Sequential()
model.add(keras.layers.Dense(input_layer_size, activation='relu', input_shape=(input_layer_size,)))
model.add(keras.layers.Dense(50, activation='relu')
model.add(keras.layers.Dense(50, activation='relu'),# kernel_regularizer=regularizers.l2(0.001)))
model.add(keras.layers.Dense(1))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 6)                 42
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                350
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 2,993
# Trainable params: 2,993
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

# %%
history = model.fit(x_train,y_train,validation_data=(x_val, y_val),epochs=100, batch_size=10,verbose=2)
# Out:
# Epoch 1/100
# 45/45 - 0s - loss: 1199.2339 - val_loss: 1060.1527
# Epoch 2/100
# 45/45 - 0s - loss: 858.1879 - val_loss: 480.2554
# Epoch 3/100
# 45/45 - 0s - loss: 193.5143 - val_loss: 56.8106
# Epoch 4/100
# 45/45 - 0s - loss: 48.3988 - val_loss: 54.1762
# Epoch 5/100
# 45/45 - 0s - loss: 46.4209 - val_loss: 52.8385
# Epoch 6/100
# 45/45 - 0s - loss: 44.9697 - val_loss: 51.7382
# Epoch 7/100
# 45/45 - 0s - loss: 43.5120 - val_loss: 50.3909
# Epoch 8/100
# 45/45 - 0s - loss: 41.8746 - val_loss: 48.0831
# Epoch 9/100
# 45/45 - 0s - loss: 40.4156 - val_loss: 46.1397
# Epoch 10/100
# 45/45 - 0s - loss: 38.9355 - val_loss: 44.8069
# Epoch 11/100
# 45/45 - 0s - loss: 36.7908 - val_loss: 42.1367
# Epoch 12/100
# 45/45 - 0s - loss: 34.8467 - val_loss: 39.9764
# Epoch 13/100
# 45/45 - 0s - loss: 33.1584 - val_loss: 38.5696
# Epoch 14/100
# 45/45 - 0s - loss: 31.1394 - val_loss: 36.0451
# Epoch 15/100
# 45/45 - 0s - loss: 28.7406 - val_loss: 34.3329
# Epoch 16/100
# 45/45 - 0s - loss: 27.4335 - val_loss: 33.0235
# Epoch 17/100
# 45/45 - 0s - loss: 25.0056 - val_loss: 29.2306
# Epoch 18/100
# 45/45 - 0s - loss: 23.0681 - val_loss: 26.1583
# Epoch 19/100
# 45/45 - 0s - loss: 20.5298 - val_loss: 25.1377
# Epoch 20/100
# 45/45 - 0s - loss: 18.6077 - val_loss: 22.5848
# Epoch 21/100
# 45/45 - 0s - loss: 17.0940 - val_loss: 20.3973
# Epoch 22/100
# 45/45 - 0s - loss: 15.6515 - val_loss: 19.1312
# Epoch 23/100
# 45/45 - 0s - loss: 14.3454 - val_loss: 18.2062
# Epoch 24/100
# 45/45 - 0s - loss: 13.4017 - val_loss: 16.8313
# Epoch 25/100
# 45/45 - 0s - loss: 12.7797 - val_loss: 16.4028
# Epoch 26/100
# 45/45 - 0s - loss: 12.1815 - val_loss: 15.2596
# Epoch 27/100
# 45/45 - 0s - loss: 11.9415 - val_loss: 15.0468
# Epoch 28/100
# 45/45 - 0s - loss: 11.6039 - val_loss: 15.0212
# Epoch 29/100
# 45/45 - 0s - loss: 11.3972 - val_loss: 14.3360
# Epoch 30/100
# 45/45 - 0s - loss: 11.3312 - val_loss: 14.3218
# Epoch 31/100
# 45/45 - 0s - loss: 11.4201 - val_loss: 14.7919
# Epoch 32/100
# 45/45 - 0s - loss: 11.1612 - val_loss: 13.9647
# Epoch 33/100
# 45/45 - 0s - loss: 11.1351 - val_loss: 14.2565
# Epoch 34/100
# 45/45 - 0s - loss: 11.0015 - val_loss: 13.9024
# Epoch 35/100
# 45/45 - 0s - loss: 11.0233 - val_loss: 13.9060
# Epoch 36/100
# 45/45 - 0s - loss: 10.9608 - val_loss: 13.6736
# Epoch 37/100
# 45/45 - 0s - loss: 11.0076 - val_loss: 14.1039
# Epoch 38/100
# 45/45 - 0s - loss: 10.7082 - val_loss: 14.5481
# Epoch 39/100
# 45/45 - 0s - loss: 10.7316 - val_loss: 13.4691
# Epoch 40/100
# 45/45 - 0s - loss: 10.9905 - val_loss: 13.6074
# Epoch 41/100
# 45/45 - 0s - loss: 10.6583 - val_loss: 14.5017
# Epoch 42/100
# 45/45 - 0s - loss: 10.5879 - val_loss: 13.2337
# Epoch 43/100
# 45/45 - 0s - loss: 10.5007 - val_loss: 14.2744
# Epoch 44/100
# 45/45 - 0s - loss: 10.5838 - val_loss: 13.0465
# Epoch 45/100
# 45/45 - 0s - loss: 10.2157 - val_loss: 13.5038
# Epoch 46/100
# 45/45 - 0s - loss: 10.5406 - val_loss: 13.3237
# Epoch 47/100
# 45/45 - 0s - loss: 10.1630 - val_loss: 12.9411
# Epoch 48/100
# 45/45 - 0s - loss: 10.0958 - val_loss: 12.8412
# Epoch 49/100
# 45/45 - 0s - loss: 9.9980 - val_loss: 13.1602
# Epoch 50/100
# 45/45 - 0s - loss: 10.0993 - val_loss: 12.4885
# Epoch 51/100
# 45/45 - 0s - loss: 9.9259 - val_loss: 14.3239
# Epoch 52/100
# 45/45 - 0s - loss: 10.0240 - val_loss: 12.8187
# Epoch 53/100
# 45/45 - 0s - loss: 9.6530 - val_loss: 12.4853
# Epoch 54/100
# 45/45 - 0s - loss: 9.7359 - val_loss: 14.0564
# Epoch 55/100
# 45/45 - 0s - loss: 9.4843 - val_loss: 12.0081
# Epoch 56/100
# 45/45 - 0s - loss: 9.6002 - val_loss: 11.8387
# Epoch 57/100
# 45/45 - 0s - loss: 9.3191 - val_loss: 12.7579
# Epoch 58/100
# 45/45 - 0s - loss: 9.4172 - val_loss: 11.6592
# Epoch 59/100
# 45/45 - 0s - loss: 9.0076 - val_loss: 12.8589
# Epoch 60/100
# 45/45 - 0s - loss: 8.8671 - val_loss: 11.4027
# Epoch 61/100
# 45/45 - 0s - loss: 8.7727 - val_loss: 11.2117
# Epoch 62/100
# 45/45 - 0s - loss: 8.5830 - val_loss: 11.0711
# Epoch 63/100
# 45/45 - 0s - loss: 8.9523 - val_loss: 12.4592
# Epoch 64/100
# 45/45 - 0s - loss: 8.3227 - val_loss: 10.9585
# Epoch 65/100
# 45/45 - 0s - loss: 8.4931 - val_loss: 10.6883
# Epoch 66/100
# 45/45 - 0s - loss: 8.3651 - val_loss: 10.4722
# Epoch 67/100
# 45/45 - 0s - loss: 8.1528 - val_loss: 10.5540
# Epoch 68/100
# 45/45 - 0s - loss: 7.8557 - val_loss: 10.4202
# Epoch 69/100
# 45/45 - 0s - loss: 7.6956 - val_loss: 9.9714
# Epoch 70/100
# 45/45 - 0s - loss: 7.6057 - val_loss: 10.0503
# Epoch 71/100
# 45/45 - 0s - loss: 7.4788 - val_loss: 11.3973
# Epoch 72/100
# 45/45 - 0s - loss: 7.4740 - val_loss: 9.7311
# Epoch 73/100
# 45/45 - 0s - loss: 7.4741 - val_loss: 9.6953
# Epoch 74/100
# 45/45 - 0s - loss: 7.2948 - val_loss: 9.2396
# Epoch 75/100
# 45/45 - 0s - loss: 7.1758 - val_loss: 8.8474
# Epoch 76/100
# 45/45 - 0s - loss: 6.7989 - val_loss: 8.8550
# Epoch 77/100
# 45/45 - 0s - loss: 6.3911 - val_loss: 8.4193
# Epoch 78/100
# 45/45 - 0s - loss: 6.1701 - val_loss: 8.2723
# Epoch 79/100
# 45/45 - 0s - loss: 6.1646 - val_loss: 8.8636
# Epoch 80/100
# 45/45 - 0s - loss: 5.8708 - val_loss: 7.9966
# Epoch 81/100
# 45/45 - 0s - loss: 5.6271 - val_loss: 7.6868
# Epoch 82/100
# 45/45 - 0s - loss: 5.4391 - val_loss: 7.3333
# Epoch 83/100
# 45/45 - 0s - loss: 5.4812 - val_loss: 7.1677
# Epoch 84/100
# 45/45 - 0s - loss: 5.1485 - val_loss: 6.9180
# Epoch 85/100
# 45/45 - 0s - loss: 4.9155 - val_loss: 6.8894
# Epoch 86/100
# 45/45 - 0s - loss: 4.8748 - val_loss: 6.4861
# Epoch 87/100
# 45/45 - 0s - loss: 4.7726 - val_loss: 6.2400
# Epoch 88/100
# 45/45 - 0s - loss: 4.5032 - val_loss: 6.2107
# Epoch 89/100
# 45/45 - 0s - loss: 4.4529 - val_loss: 5.8683
# Epoch 90/100
# 45/45 - 0s - loss: 4.2609 - val_loss: 5.7941
# Epoch 91/100
# 45/45 - 0s - loss: 4.1354 - val_loss: 6.4378
# Epoch 92/100
# 45/45 - 0s - loss: 4.1177 - val_loss: 5.7605
# Epoch 93/100
# 45/45 - 0s - loss: 3.9498 - val_loss: 5.4621
# Epoch 94/100
# 45/45 - 0s - loss: 3.9191 - val_loss: 5.1223
# Epoch 95/100
# 45/45 - 0s - loss: 3.8706 - val_loss: 5.6761
# Epoch 96/100
# 45/45 - 0s - loss: 3.6846 - val_loss: 5.2596
# Epoch 97/100
# 45/45 - 0s - loss: 3.4404 - val_loss: 4.7029
# Epoch 98/100
# 45/45 - 0s - loss: 3.4314 - val_loss: 5.2240
# Epoch 99/100
# 45/45 - 0s - loss: 3.3284 - val_loss: 4.5017
# Epoch 100/100
# 45/45 - 0s - loss: 3.3096 - val_loss: 4.7274

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
axes = plt.gca()
axes.set_ylim([0,20])
plt.show()

# %%
keras_predictions = model.predict(x_test, verbose=2)
# Out:
# 16/16 - 0s

# %%
print("Error on test data")
mse_test = np.mean(np.power(keras_predictions - y_test.values, 2))
print("MSE: ", mse_test) #2.6873526

mae_test = np.mean(np.abs(keras_predictions-y_test.values))
print("MAE: ", mae_test) # 1.12

mape_test = 100*np.mean(np.abs(np.divide(keras_predictions - y_test.values, y_test.values)))
print("MAPE: ", mape_test, "%") # 3.574
# Out:
# Error on test data
# MSE:  17.293729050071335
# MAE:  3.834389052270368
# MAPE:  13.992457641576618 %

# %%
plt.figure(figsize=(16,9))
plt.plot(y_test.values, label='Missing QTOT')
plt.plot(keras_predictions, label='Estimated QTOT simple model')
plt.legend()

# %% [markdown]
# # Improve model

# %% [markdown]
# ### Adding a dropout layer

# %%
from keras.layers import Dropout

input_layer_size = x_train.columns.size

improved_model = keras.Sequential()
improved_model.add(keras.layers.Dense(input_layer_size, activation='relu', input_shape=(input_layer_size,)))
improved_model.add(keras.layers.Dense(50, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
improved_model.add(keras.layers.Dropout(0.1))
improved_model.add(keras.layers.Dense(50, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
improved_model.add(keras.layers.Dense(1))

# %%
improved_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 6)                 42
# _________________________________________________________________
# dense_5 (Dense)              (None, 50)                350
# _________________________________________________________________
# dropout (Dropout)            (None, 50)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 2,993
# Trainable params: 2,993
# Non-trainable params: 0
# _________________________________________________________________

# %%
improved_model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

# %% [markdown]
# ### Early stopping

# %%
from keras.callbacks import EarlyStopping

callback = EarlyStopping(monitor='val_loss', patience=3)


improved_history = improved_model.fit(x_train,y_train,validation_data=(x_val, y_val),epochs=200, batch_size=10, callbacks=[callback],verbose=2)
# Out:
# Epoch 1/200
# 45/45 - 0s - loss: 1178.1859 - val_loss: 1021.8376
# Epoch 2/200
# 45/45 - 0s - loss: 814.2495 - val_loss: 454.6734
# Epoch 3/200
# 45/45 - 0s - loss: 191.2715 - val_loss: 52.1701
# Epoch 4/200
# 45/45 - 0s - loss: 52.1064 - val_loss: 51.1941
# Epoch 5/200
# 45/45 - 0s - loss: 53.2936 - val_loss: 50.2441
# Epoch 6/200
# 45/45 - 0s - loss: 54.1883 - val_loss: 48.9776
# Epoch 7/200
# 45/45 - 0s - loss: 48.6374 - val_loss: 48.2571
# Epoch 8/200
# 45/45 - 0s - loss: 48.1154 - val_loss: 46.6705
# Epoch 9/200
# 45/45 - 0s - loss: 44.5709 - val_loss: 46.3798
# Epoch 10/200
# 45/45 - 0s - loss: 44.6825 - val_loss: 44.2190
# Epoch 11/200
# 45/45 - 0s - loss: 46.3012 - val_loss: 42.9165
# Epoch 12/200
# 45/45 - 0s - loss: 43.0319 - val_loss: 42.0933
# Epoch 13/200
# 45/45 - 0s - loss: 43.1918 - val_loss: 41.5419
# Epoch 14/200
# 45/45 - 0s - loss: 41.6577 - val_loss: 39.9036
# Epoch 15/200
# 45/45 - 0s - loss: 38.1054 - val_loss: 37.4927
# Epoch 16/200
# 45/45 - 0s - loss: 37.8502 - val_loss: 36.1988
# Epoch 17/200
# 45/45 - 0s - loss: 35.8027 - val_loss: 34.7340
# Epoch 18/200
# 45/45 - 0s - loss: 36.6089 - val_loss: 33.8613
# Epoch 19/200
# 45/45 - 0s - loss: 35.0226 - val_loss: 34.0046
# Epoch 20/200
# 45/45 - 0s - loss: 34.1299 - val_loss: 30.1431
# Epoch 21/200
# 45/45 - 0s - loss: 32.0620 - val_loss: 29.3435
# Epoch 22/200
# 45/45 - 0s - loss: 29.5027 - val_loss: 28.5827
# Epoch 23/200
# 45/45 - 0s - loss: 30.3914 - val_loss: 25.7181
# Epoch 24/200
# 45/45 - 0s - loss: 27.5832 - val_loss: 24.3846
# Epoch 25/200
# 45/45 - 0s - loss: 27.9948 - val_loss: 22.9086
# Epoch 26/200
# 45/45 - 0s - loss: 23.4574 - val_loss: 21.4645
# Epoch 27/200
# 45/45 - 0s - loss: 23.2247 - val_loss: 20.4884
# Epoch 28/200
# 45/45 - 0s - loss: 23.0873 - val_loss: 19.0073
# Epoch 29/200
# 45/45 - 0s - loss: 20.1408 - val_loss: 18.0616
# Epoch 30/200
# 45/45 - 0s - loss: 21.7854 - val_loss: 17.3071
# Epoch 31/200
# 45/45 - 0s - loss: 19.8668 - val_loss: 16.0460
# Epoch 32/200
# 45/45 - 0s - loss: 19.6295 - val_loss: 15.0879
# Epoch 33/200
# 45/45 - 0s - loss: 18.2974 - val_loss: 14.7691
# Epoch 34/200
# 45/45 - 0s - loss: 17.8610 - val_loss: 13.9828
# Epoch 35/200
# 45/45 - 0s - loss: 17.7020 - val_loss: 13.8457
# Epoch 36/200
# 45/45 - 0s - loss: 17.1820 - val_loss: 13.1499
# Epoch 37/200
# 45/45 - 0s - loss: 16.4184 - val_loss: 12.8042
# Epoch 38/200
# 45/45 - 0s - loss: 16.8892 - val_loss: 12.5179
# Epoch 39/200
# 45/45 - 0s - loss: 16.2836 - val_loss: 12.3694
# Epoch 40/200
# 45/45 - 0s - loss: 16.2349 - val_loss: 12.1177
# Epoch 41/200
# 45/45 - 0s - loss: 15.2098 - val_loss: 11.9231
# Epoch 42/200
# 45/45 - 0s - loss: 16.0251 - val_loss: 11.7105
# Epoch 43/200
# 45/45 - 0s - loss: 14.7059 - val_loss: 11.5631
# Epoch 44/200
# 45/45 - 0s - loss: 15.3152 - val_loss: 11.4303
# Epoch 45/200
# 45/45 - 0s - loss: 15.8077 - val_loss: 11.4954
# Epoch 46/200
# 45/45 - 0s - loss: 14.4926 - val_loss: 11.1347
# Epoch 47/200
# 45/45 - 0s - loss: 13.9431 - val_loss: 11.3197
# Epoch 48/200
# 45/45 - 0s - loss: 15.1097 - val_loss: 10.9031
# Epoch 49/200
# 45/45 - 0s - loss: 14.7630 - val_loss: 10.7306
# Epoch 50/200
# 45/45 - 0s - loss: 15.4223 - val_loss: 11.8671
# Epoch 51/200
# 45/45 - 0s - loss: 15.2471 - val_loss: 10.4578
# Epoch 52/200
# 45/45 - 0s - loss: 13.1937 - val_loss: 10.2696
# Epoch 53/200
# 45/45 - 0s - loss: 14.0137 - val_loss: 10.2382
# Epoch 54/200
# 45/45 - 0s - loss: 13.6795 - val_loss: 10.1078
# Epoch 55/200
# 45/45 - 0s - loss: 13.2438 - val_loss: 10.0559
# Epoch 56/200
# 45/45 - 0s - loss: 14.3586 - val_loss: 9.8818
# Epoch 57/200
# 45/45 - 0s - loss: 13.2022 - val_loss: 9.5903
# Epoch 58/200
# 45/45 - 0s - loss: 13.9942 - val_loss: 9.3882
# Epoch 59/200
# 45/45 - 0s - loss: 15.9237 - val_loss: 9.3357
# Epoch 60/200
# 45/45 - 0s - loss: 12.7993 - val_loss: 9.4825
# Epoch 61/200
# 45/45 - 0s - loss: 12.6962 - val_loss: 8.9476
# Epoch 62/200
# 45/45 - 0s - loss: 13.0840 - val_loss: 9.3690
# Epoch 63/200
# 45/45 - 0s - loss: 14.5192 - val_loss: 8.7232
# Epoch 64/200
# 45/45 - 0s - loss: 12.7429 - val_loss: 8.4852
# Epoch 65/200
# 45/45 - 0s - loss: 13.4467 - val_loss: 8.3700
# Epoch 66/200
# 45/45 - 0s - loss: 13.2543 - val_loss: 8.3568
# Epoch 67/200
# 45/45 - 0s - loss: 10.6408 - val_loss: 8.0243
# Epoch 68/200
# 45/45 - 0s - loss: 12.9571 - val_loss: 8.1083
# Epoch 69/200
# 45/45 - 0s - loss: 11.5907 - val_loss: 7.8135
# Epoch 70/200
# 45/45 - 0s - loss: 11.4347 - val_loss: 7.7955
# Epoch 71/200
# 45/45 - 0s - loss: 12.3484 - val_loss: 7.5855
# Epoch 72/200
# 45/45 - 0s - loss: 12.5131 - val_loss: 7.4690
# Epoch 73/200
# 45/45 - 0s - loss: 12.3602 - val_loss: 7.4055
# Epoch 74/200
# 45/45 - 0s - loss: 11.5143 - val_loss: 7.0768
# Epoch 75/200
# 45/45 - 0s - loss: 11.8379 - val_loss: 6.8629
# Epoch 76/200
# 45/45 - 0s - loss: 10.7780 - val_loss: 6.7145
# Epoch 77/200
# 45/45 - 0s - loss: 11.5197 - val_loss: 6.6525
# Epoch 78/200
# 45/45 - 0s - loss: 11.7285 - val_loss: 6.6838
# Epoch 79/200
# 45/45 - 0s - loss: 10.8986 - val_loss: 6.3614
# Epoch 80/200
# 45/45 - 0s - loss: 11.1733 - val_loss: 6.5306
# Epoch 81/200
# 45/45 - 0s - loss: 11.0249 - val_loss: 6.1849
# Epoch 82/200
# 45/45 - 0s - loss: 10.8536 - val_loss: 6.0185
# Epoch 83/200
# 45/45 - 0s - loss: 11.4047 - val_loss: 5.6789
# Epoch 84/200
# 45/45 - 0s - loss: 10.4034 - val_loss: 5.7633
# Epoch 85/200
# 45/45 - 0s - loss: 10.1826 - val_loss: 5.7419
# Epoch 86/200
# 45/45 - 0s - loss: 11.1946 - val_loss: 5.7080

# %%
plt.plot(improved_history.history['loss'])
plt.plot(improved_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
axes = plt.gca()
axes.set_ylim([0,10])
plt.show()

# %%
improved_keras_predictions = improved_model.predict(x_test, verbose=2)
# Out:
# 16/16 - 0s

# %%
print("Error on test data")
mse_test = np.mean(np.power(improved_keras_predictions - y_test.values, 2))
print("MSE: ", mse_test) #2.6873526

mae_test = np.mean(np.abs(improved_keras_predictions-y_test.values))
print("MAE: ", mae_test) # 1.12

mape_test = 100*np.mean(np.abs(np.divide(improved_keras_predictions - y_test.values, y_test.values)))
print("MAPE: ", mape_test, "%") # 3.574
# Out:
# Error on test data
# MSE:  20.193152601204666
# MAE:  4.008606197787497
# MAPE:  14.97425305808692 %

# %%
plt.figure(figsize=(16,9))
plt.plot(y_test.values, label='Missing QTOT')
plt.plot(keras_predictions, label='Estimated QTOT simple model')
plt.plot(improved_keras_predictions, label='Estimated QTOT improved model')
plt.legend()

# %% [markdown]
# # On a smaller training set?

# %%
train_set_small = train_set.sample(frac=0.1, replace=False)
val_set_small = val_set.sample(frac=0.1, replace=False)

x_train_small = train_set_small.drop(columns='QTOT')
y_train_small = train_set_small[['QTOT']]

x_val_small = val_set_small.drop(columns='QTOT')
y_val_small = val_set_small[['QTOT']]

plt.figure(figsize=(16,9))
plt.scatter(y_train_small.index, y_train_small.values, color='black', label='Train')
plt.scatter(y_val_small.index, y_val_small['QTOT'], color='green', label='Val')
plt.scatter(y_test.index, y_test.values, color='red', label='test')
plt.legend()

# %%
model = keras.Sequential()
model.add(keras.layers.Dense(input_layer_size, activation='relu', input_shape=(input_layer_size,)))
model.add(keras.layers.Dense(50, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
model.add(keras.layers.Dense(50, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
model.add(keras.layers.Dense(1))

# %%
model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

# %%
simple_history_small = model.fit(x_train_small,y_train_small,validation_data=(x_val_small, y_val_small),epochs=100, batch_size=10,verbose=2)
# Out:
# Epoch 1/100
# 5/5 - 0s - loss: 1204.5184 - val_loss: 1134.4248
# Epoch 2/100
# 5/5 - 0s - loss: 1198.0173 - val_loss: 1128.1567
# Epoch 3/100
# 5/5 - 0s - loss: 1191.3253 - val_loss: 1121.4180
# Epoch 4/100
# 5/5 - 0s - loss: 1183.9144 - val_loss: 1113.8435
# Epoch 5/100
# 5/5 - 0s - loss: 1175.5447 - val_loss: 1105.1086
# Epoch 6/100
# 5/5 - 0s - loss: 1165.8698 - val_loss: 1094.5054
# Epoch 7/100
# 5/5 - 0s - loss: 1153.6011 - val_loss: 1081.8040
# Epoch 8/100
# 5/5 - 0s - loss: 1139.4878 - val_loss: 1066.6559
# Epoch 9/100
# 5/5 - 0s - loss: 1122.5139 - val_loss: 1048.6863
# Epoch 10/100
# 5/5 - 0s - loss: 1103.0094 - val_loss: 1027.3724
# Epoch 11/100
# 5/5 - 0s - loss: 1079.4845 - val_loss: 1002.5558
# Epoch 12/100
# 5/5 - 0s - loss: 1051.3979 - val_loss: 973.6864
# Epoch 13/100
# 5/5 - 0s - loss: 1020.3391 - val_loss: 939.6971
# Epoch 14/100
# 5/5 - 0s - loss: 982.5190 - val_loss: 900.4698
# Epoch 15/100
# 5/5 - 0s - loss: 938.8057 - val_loss: 855.3242
# Epoch 16/100
# 5/5 - 0s - loss: 890.4514 - val_loss: 803.5505
# Epoch 17/100
# 5/5 - 0s - loss: 833.4252 - val_loss: 745.5519
# Epoch 18/100
# 5/5 - 0s - loss: 769.1180 - val_loss: 680.5559
# Epoch 19/100
# 5/5 - 0s - loss: 698.5028 - val_loss: 608.7000
# Epoch 20/100
# 5/5 - 0s - loss: 621.2609 - val_loss: 532.2584
# Epoch 21/100
# 5/5 - 0s - loss: 539.0318 - val_loss: 452.9793
# Epoch 22/100
# 5/5 - 0s - loss: 453.8561 - val_loss: 373.3489
# Epoch 23/100
# 5/5 - 0s - loss: 372.6761 - val_loss: 294.6610
# Epoch 24/100
# 5/5 - 0s - loss: 287.4354 - val_loss: 223.0340
# Epoch 25/100
# 5/5 - 0s - loss: 214.1378 - val_loss: 159.4519
# Epoch 26/100
# 5/5 - 0s - loss: 151.7245 - val_loss: 108.0285
# Epoch 27/100
# 5/5 - 0s - loss: 101.0615 - val_loss: 71.4926
# Epoch 28/100
# 5/5 - 0s - loss: 66.0358 - val_loss: 49.4106
# Epoch 29/100
# 5/5 - 0s - loss: 45.3719 - val_loss: 39.8428
# Epoch 30/100
# 5/5 - 0s - loss: 36.9047 - val_loss: 38.2502
# Epoch 31/100
# 5/5 - 0s - loss: 34.8481 - val_loss: 39.8564
# Epoch 32/100
# 5/5 - 0s - loss: 35.3186 - val_loss: 41.2784
# Epoch 33/100
# 5/5 - 0s - loss: 35.9808 - val_loss: 41.4303
# Epoch 34/100
# 5/5 - 0s - loss: 35.8057 - val_loss: 40.6454
# Epoch 35/100
# 5/5 - 0s - loss: 35.1557 - val_loss: 39.9059
# Epoch 36/100
# 5/5 - 0s - loss: 34.6667 - val_loss: 38.6881
# Epoch 37/100
# 5/5 - 0s - loss: 33.8770 - val_loss: 38.0427
# Epoch 38/100
# 5/5 - 0s - loss: 33.6473 - val_loss: 37.5762
# Epoch 39/100
# 5/5 - 0s - loss: 33.4877 - val_loss: 37.2316
# Epoch 40/100
# 5/5 - 0s - loss: 33.3376 - val_loss: 37.0389
# Epoch 41/100
# 5/5 - 0s - loss: 33.1467 - val_loss: 37.0216
# Epoch 42/100
# 5/5 - 0s - loss: 33.0334 - val_loss: 37.0577
# Epoch 43/100
# 5/5 - 0s - loss: 32.8450 - val_loss: 36.9523
# Epoch 44/100
# 5/5 - 0s - loss: 32.6862 - val_loss: 36.7611
# Epoch 45/100
# 5/5 - 0s - loss: 32.5289 - val_loss: 36.5524
# Epoch 46/100
# 5/5 - 0s - loss: 32.3699 - val_loss: 36.3576
# Epoch 47/100
# 5/5 - 0s - loss: 32.2222 - val_loss: 36.0786
# Epoch 48/100
# 5/5 - 0s - loss: 32.0707 - val_loss: 35.7538
# Epoch 49/100
# 5/5 - 0s - loss: 31.9345 - val_loss: 35.5958
# Epoch 50/100
# 5/5 - 0s - loss: 31.8173 - val_loss: 35.4129
# Epoch 51/100
# 5/5 - 0s - loss: 31.6189 - val_loss: 35.2660
# Epoch 52/100
# 5/5 - 0s - loss: 31.4499 - val_loss: 35.1078
# Epoch 53/100
# 5/5 - 0s - loss: 31.3898 - val_loss: 34.9259
# Epoch 54/100
# 5/5 - 0s - loss: 31.1137 - val_loss: 34.8832
# Epoch 55/100
# 5/5 - 0s - loss: 30.9535 - val_loss: 34.7732
# Epoch 56/100
# 5/5 - 0s - loss: 30.7754 - val_loss: 34.8106
# Epoch 57/100
# 5/5 - 0s - loss: 30.6172 - val_loss: 34.6865
# Epoch 58/100
# 5/5 - 0s - loss: 30.4598 - val_loss: 34.5498
# Epoch 59/100
# 5/5 - 0s - loss: 30.3355 - val_loss: 34.3100
# Epoch 60/100
# 5/5 - 0s - loss: 30.1825 - val_loss: 34.2321
# Epoch 61/100
# 5/5 - 0s - loss: 29.9301 - val_loss: 33.9247
# Epoch 62/100
# 5/5 - 0s - loss: 29.8951 - val_loss: 33.6261
# Epoch 63/100
# 5/5 - 0s - loss: 29.6272 - val_loss: 33.5077
# Epoch 64/100
# 5/5 - 0s - loss: 29.4787 - val_loss: 33.4884
# Epoch 65/100
# 5/5 - 0s - loss: 29.2756 - val_loss: 33.3412
# Epoch 66/100
# 5/5 - 0s - loss: 29.1182 - val_loss: 33.1737
# Epoch 67/100
# 5/5 - 0s - loss: 29.0016 - val_loss: 33.0175
# Epoch 68/100
# 5/5 - 0s - loss: 28.7737 - val_loss: 32.7411
# Epoch 69/100
# 5/5 - 0s - loss: 28.6498 - val_loss: 32.5051
# Epoch 70/100
# 5/5 - 0s - loss: 28.5846 - val_loss: 32.2921
# Epoch 71/100
# 5/5 - 0s - loss: 28.2686 - val_loss: 32.2721
# Epoch 72/100
# 5/5 - 0s - loss: 28.0823 - val_loss: 32.1836
# Epoch 73/100
# 5/5 - 0s - loss: 27.9516 - val_loss: 32.1185
# Epoch 74/100
# 5/5 - 0s - loss: 27.7888 - val_loss: 31.9899
# Epoch 75/100
# 5/5 - 0s - loss: 27.6530 - val_loss: 31.8557
# Epoch 76/100
# 5/5 - 0s - loss: 27.4637 - val_loss: 31.5682
# Epoch 77/100
# 5/5 - 0s - loss: 27.2575 - val_loss: 31.3381
# Epoch 78/100
# 5/5 - 0s - loss: 27.1033 - val_loss: 31.0325
# Epoch 79/100
# 5/5 - 0s - loss: 27.2082 - val_loss: 30.7342
# Epoch 80/100
# 5/5 - 0s - loss: 26.8123 - val_loss: 30.6980
# Epoch 81/100
# 5/5 - 0s - loss: 26.5220 - val_loss: 30.6353
# Epoch 82/100
# 5/5 - 0s - loss: 26.4620 - val_loss: 30.5702
# Epoch 83/100
# 5/5 - 0s - loss: 26.3167 - val_loss: 30.4989
# Epoch 84/100
# 5/5 - 0s - loss: 26.1892 - val_loss: 30.3471
# Epoch 85/100
# 5/5 - 0s - loss: 25.9783 - val_loss: 29.9028
# Epoch 86/100
# 5/5 - 0s - loss: 25.6924 - val_loss: 29.7179
# Epoch 87/100
# 5/5 - 0s - loss: 25.5850 - val_loss: 29.5886
# Epoch 88/100
# 5/5 - 0s - loss: 25.2960 - val_loss: 29.2849
# Epoch 89/100
# 5/5 - 0s - loss: 25.2344 - val_loss: 28.9623
# Epoch 90/100
# 5/5 - 0s - loss: 25.0632 - val_loss: 28.7786
# Epoch 91/100
# 5/5 - 0s - loss: 24.9919 - val_loss: 28.7057
# Epoch 92/100
# 5/5 - 0s - loss: 24.6887 - val_loss: 28.4578
# Epoch 93/100
# 5/5 - 0s - loss: 24.5505 - val_loss: 28.2971
# Epoch 94/100
# 5/5 - 0s - loss: 24.3884 - val_loss: 28.4127
# Epoch 95/100
# 5/5 - 0s - loss: 24.1426 - val_loss: 28.2753
# Epoch 96/100
# 5/5 - 0s - loss: 23.9946 - val_loss: 27.9630
# Epoch 97/100
# 5/5 - 0s - loss: 23.7958 - val_loss: 27.8010
# Epoch 98/100
# 5/5 - 0s - loss: 23.6106 - val_loss: 27.6961
# Epoch 99/100
# 5/5 - 0s - loss: 23.4236 - val_loss: 27.4776
# Epoch 100/100
# 5/5 - 0s - loss: 23.1995 - val_loss: 27.1978

# %%
plt.plot(simple_history_small.history['loss'])
plt.plot(simple_history_small.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
axes = plt.gca()
axes.set_ylim([0,30])
plt.show()

# %%
from keras.layers import Dropout

input_layer_size = x_train.columns.size

improved_model_small = keras.Sequential()
improved_model_small.add(keras.layers.Dense(input_layer_size, activation='relu', input_shape=(input_layer_size,)))
improved_model_small.add(keras.layers.Dense(50, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
improved_model_small.add(keras.layers.Dropout(0.1))
improved_model_small.add(keras.layers.Dense(50, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
improved_model_small.add(keras.layers.Dense(1))
